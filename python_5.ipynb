# %% [markdown]
# <a href="https://colab.research.google.com/github/guramritpandher/my_work/blob/branch3/python_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Constructor**

# %%
#special method which runs when code is first run, it holds all the code which does not require user access
#like conectivity to database,  internet, or any such things
#__init__()
class User:
  def __init__(self):
    print("ONAL")

user_1=User()
user_1.id="001"
user_1.age=23
print(user_1.id)
print(user_1.age)
# Out:
# ONAL
# 001
# 23

# %%
class emp:
    def __init__(self):
        self.name = 'xyz'
        self.salary = 4000

    def show(self):
        print(self.name)
        print(self.salary)

e1 = emp()
print("Dictionary form :", vars(e1))      #vars() – This function displays the attribute of an instance in the form of an dictionary
print(dir(e1))    #This function displays more attributes than vars function,as it is not limited to instance. It displays the class attributes as well. It also displays the attributes of its ancestor classes.
# Out:
# Dictionary form : {'name': 'xyz', 'salary': 4000}
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'name', 'salary', 'show']

# %%
#self is an object in python as everythin in python is a object
#the object whith which we are working currently in our code is self

# %% [markdown]
# # **INHERITANCE**

# %%
'''Inheritance is a fundamental concept in object-oriented programming (OOP) that
allows a class (called a child or derived class) to inherit attributes and methods
from another class (called a parent or base class).'''

#####SYNTAX#####
class ParentClass:
    # Parent class code here
    pass
class ChildClass(ParentClass):
    # Child class code here
    pass



#EXAMPLE:
# Parent class
class Animal:
    def __init__(self, name):
        self.name = name  # Initialize the name attribute

    def speak(self):
        pass  # Placeholder method to be overridden by child classes

# Child class inheriting from Animal
class Dog(Animal):
    def speak(self):
        return f"{self.name} barks!"  # Override the speak method

# Creating an instance of Dog
dog = Dog("Buddy")
print(dog.speak())  # Output: Buddy says Woof!
# Out:
# Buddy barks!

# %%
# A Python program to demonstrate inheritance
class Person(object):

  def __init__(self, name, id):
    self.name = name
    self.id = id

  def Display(self):
    print(self.name, self.id)

emp = Person("Satyam", 102) # An Object of Person
emp.Display()

class Emp(Person):

  def Print(self):
    print("Emp class called")

Emp_details = Emp("Mayank", 103)

# calling parent class function
Emp_details.Display()

# Calling child class function
Emp_details.Print()
# Out:
# Satyam 102
# Mayank 103
# Emp class called

# %%
#Create a base class Animal with a method speak(). Then, create a derived class Dog that overrides the speak() method to print "Bark!".

class Animal:
  def speak(self):
    pass

class Dog(Animal):
  def speak(self):
    return "Barks"

class Cat(Animal):
  def speak(self):
    return "Meoww"

dog1=Dog()
cat1=Cat()
print(dog1.speak())
print(cat1.speak())
# Out:
# Barks
# Meoww

# %%
class Animal:
  def __init__(self,name):
    self.name=name

  def speak(self):
    pass

class Lion(Animal):
  def speak(self):
    return f"{self.name},Rrooaarr!!"

lion1=Lion("King")
print(lion1.speak())
# Out:
# King,Rrooaarr!!

# %%
#super() function is used to call the parent class’s methods

# Parent Class: Person
class Person:
    def __init__(self, name, idnumber):
        self.name = name
        self.idnumber = idnumber

    def display(self):
        print(self.name)
        print(self.idnumber)

# Child Class: Employee
class Employee(Person):
    def __init__(self, name, idnumber, salary, post):
        super().__init__(name, idnumber)  # Using super() to call Person's __init__()
        self.salary = salary
        self.post = post

# %%
#Types of Inheritance in Python
# 1. Single Inheritance
class Person:
    def __init__(self, name):
        self.name = name

class Employee(Person):  # Employee inherits from Person
    def __init__(self, name, salary):
        super().__init__(name)
        self.salary = salary

# 2. Multiple Inheritance
class Job:
    def __init__(self, salary):
        self.salary = salary

class EmployeePersonJob(Employee, Job):  # Inherits from both Employee and Job
    def __init__(self, name, salary):
        Employee.__init__(self, name, salary)  # Initialize Employee
        Job.__init__(self, salary)            # Initialize Job

# 3. Multilevel Inheritance
class Manager(EmployeePersonJob):  # Inherits from EmployeePersonJob
    def __init__(self, name, salary, department):
        EmployeePersonJob.__init__(self, name, salary)  # Explicitly initialize EmployeePersonJob
        self.department = department

# 4. Hierarchical Inheritance
class AssistantManager(EmployeePersonJob):  # Inherits from EmployeePersonJob
    def __init__(self, name, salary, team_size):
        EmployeePersonJob.__init__(self, name, salary)  # Explicitly initialize EmployeePersonJob
        self.team_size = team_size

# 5. Hybrid Inheritance (Multiple + Multilevel)
class SeniorManager(Manager, AssistantManager):  # Inherits from both Manager and AssistantManager
    def __init__(self, name, salary, department, team_size):
        Manager.__init__(self, name, salary, department)        # Initialize Manager
        AssistantManager.__init__(self, name, salary, team_size)  # Initialize AssistantManager

# Creating objects to show inheritance

# Single Inheritance
emp = Employee("John", 40000)
print(emp.name, emp.salary)

# Multiple Inheritance
emp2 = EmployeePersonJob("Alice", 50000)
print(emp2.name, emp2.salary)

# Multilevel Inheritance
mgr = Manager("Bob", 60000, "HR")
print(mgr.name, mgr.salary, mgr.department)

# Hierarchical Inheritance
asst_mgr = AssistantManager("Charlie", 45000, 10)
print(asst_mgr.name, asst_mgr.salary, asst_mgr.team_size)

# Hybrid Inheritance
sen_mgr = SeniorManager("David", 70000, "Finance", 20)
print(sen_mgr.name, sen_mgr.salary, sen_mgr.department, sen_mgr.team_size)
# Out:
# John 40000
# Alice 50000
# Bob 60000 HR
# Charlie 45000 10
# David 70000 Finance 20

# %% [markdown]
# # **ENCAPSULATION**

# %%
''' It includes kkeping ur attributes or methos private for limited access,
and using getter and setter method for the purpose if any, getter method helps to get that
particular where as setter helps to the changes but according to set conditions only.'''
# To make our attributes private we add __ in front of it:
class Protected:
    def __init__(self):
        self._age = 30  # Protected attribute

class Subclass(Protected):
    def display_age(self):
        print(self._age)  # Accessible in subclass

obj = Subclass()
obj.display_age()
# Out:
# 30

# %%
#Earlier we created atm and lets use encapsulation in it
def __init__(self):
  self.__pin=""               #Made our attributes and methods private
  self.__balance=0

  self.__menu()

def get_pin(self):            #created getter method to get access to pin
  return self.__pin

def set_pin(self,new_pin):    #created setter method to do changes in pin but according to the logic and conditions set
  if type(new_pin)==str:
    self.__pin=new_pin
    print("Pin changed")
  else:
    print("Not allowed")

# %% [markdown]
# # **POLYMORPHISM**

# %%
'''It allows the same function or method to work differently based on the object
it is called on.Is mainly used in methods, functions, and operators to make code
more flexible and reusable.'''
#Method Overriding:

class Animal:
    def make_sound(self):
        return "Some generic sound"

class Dog(Animal):
    def make_sound(self):
        return "Bark!"

class Cat(Animal):
    def make_sound(self):
        return "Meow!"

dog = Dog()
cat = Cat()

print(dog.make_sound())
print(cat.make_sound())
# Out:
# Bark!
# Meow!

# %%
#Method Overloading (Compile-time Polymorphism):
'''Python does not support method overloading directly.
Instead, we can handle different numbers of arguments using default values or *args.'''
class MathOperations:
    def add(self, a, b, c=0):
        return a + b + c

math_op = MathOperations()
print(math_op.add(5, 10))      # Output: 15
print(math_op.add(5, 10, 20))  # Output: 35
# Out:
# 15
# 35

# %%
#Operator Overloading:
#Python allows operators like +, -, *, etc., to be used in different ways based on the object type.
class Book:
    def __init__(self, pages):
        self.pages = pages

    def __add__(self, other):
        return Book(self.pages + other.pages)

    def __str__(self):
        return f"Book with {self.pages} pages"

book1 = Book(200)
book2 = Book(150)
book3 = book1 + book2  # Uses __add__()

print(book3)
# Out:
# Book with 350 pages

# %%
#Polymorphism with Functions and Objects
#A function can accept different types of objects and work with them without knowing their class.
class Bird:
    def fly(self):
        return "Flies in the sky"

class Airplane:
    def fly(self):
        return "Flies using engines"

def make_it_fly(obj):
    print(obj.fly())

bird = Bird()
plane = Airplane()

make_it_fly(bird)
make_it_fly(plane)
# Out:
# Flies in the sky
# Flies using engines

# %% [markdown]
# # **ABSTRACTION**

# %%
#helps to hide unnecessary details and only show the relevant information to the user

#Abstract Class
'''An abstract class is a class that cannot be instantiated (you cannot create objects from it).
It is meant to be a blueprint for other classes.'''

#Abstract Method
'''An abstract method is a method that must be implemented in the child class.
It does not have any code in the abstract class'''

# %%
from abc import ABC, abstractmethod  # Import ABC module

# Step 1: Create an Abstract Class
class Vehicle(ABC):
    @abstractmethod  # Abstract Method (must be implemented in child class)
    def start(self):
        pass

    @abstractmethod
    def stop(self):
        pass

# Step 2: Create a Child Class
class Car(Vehicle):
    def start(self):
        print("Car is starting with key ignition.")

    def stop(self):
        print("Car is stopping by applying brakes.")

# Step 3: Use the Child Class
my_car = Car()
my_car.start()
my_car.stop()
# Out:
# Car is starting with key ignition.
# Car is stopping by applying brakes.

# %% [markdown]
# # **Special Method/Magic Method**

# %%
# methods starting and ending with double underscores ‘__’.
#Special methods help us customize how objects behave in Python

#__str__()method The __str__ method is called when we use print(object)
class Car:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

    def __str__(self):
        return f"{self.brand} {self.model}"

# Creating an object
my_car = Car("Toyota", "Fortuner")
print(my_car)
# Out:
# Toyota Fortuner

# %%
# __repr__ Method (Official Representation)
#The __repr__ method provides an official string representation (for debugging).

class Car:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

    def __repr__(self):
        return f"Car('{self.brand}', '{self.model}')"

# Creating an object
my_car = Car("Toyota", "Innova")
print(repr(my_car))
# Out:
# Car('Toyota', 'Innova')

# %%
# __add__ Method (Operator Overloading)
# The __add__ method allows us to customize how objects are added together using
class Wallet:
    def __init__(self, amount):
        self.amount = amount

    def __add__(self, other):
        return Wallet(self.amount + other.amount)

    def __str__(self):
        return f"Wallet Balance: ${self.amount}"

# Creating wallet objects
wallet1 = Wallet(50)
wallet2 = Wallet(30)

wallet3 = wallet1 + wallet2
print(wallet3)  # Output: Wallet Balance: $80
# Out:
# Wallet Balance: $80
